# %%
majorolympgods = [
    ['Venus', 'Aphrodite', 'Cypris', 'Cytherea'],
    ['Apollo', 'Apollon', 'Phoebus'],
    ['Zeus', 'Jupiter', 'Jove', 'Cronides', 'Cronion'],
    ['Hera', 'Juno'],
    ['Ares', 'Mars', 'Enyalius'],
    ['Athena', 'Athene', 'Minerva', 'Pallas', 'Tritogeneia'],
    ['Demeter', 'Ceres', 'Deo'],
    ['Dionysus', 'Liber', 'Bacchus', 'Lyaeus'],
    ['Hephaestus', 'Hepheastus', 'Vulcan', 'Vulcanos'],
    ['Hermes', 'Mercury', 'Mercurius', 'Argeiphontes'],
    ['Hestia', 'Vesta'],
    ['Poseidon', 'Neptune', 'Neptunus', 'Cronides'],
    ['Artemis', 'Phoebe', 'Diana'],
    ['Helios', 'Helius'],
    ['Hades']
]

otherolympgods = [
    ['Aglaea', 'Aglaia'],
    ['Aegle', 'Aigle'],
    ['Akeso'],
    ['Alexiares'],
    ['Anicitus', 'Aniketos'],
    ['Asclepius', 'Aesculapius'],
    ['Ariadne'],
    ['Bia'],
    ['Clymene', 'Klymene'],
    ['Clio', 'Kleio'],
    ['Cratus'],
    ['Deimus', 'Metus'],
    ['Dione'],
    ['Eileithyia', 'Lucina'],
    ['Enyo', 'Bellona'],
    ['Epione'],
    ['Eris', 'Discordia'],
    ['Eros', 'Cupid'],
    ['Euronyme'],
    ['Ganymedes', 'Ganymede', 'Catamitus'],
    ['Harmonia', 'Concordia'],
    ['Hebe', 'Juventas'],
    ['Heracles', 'Hercules'],
    ['Hestia', 'Vesta'],
    ['Hygeia', 'Salus'],
    ['Hymenaeus','Hymen', 'Hymenaios'],
    ['Iaso'],
    ['Iris'],
    ['Laertes'],
    ['Leto', 'Latona'],
    ['Litae', 'Litai'],
    ['Nike', 'Victoria'],
    ['Paeon', 'Paion'],
    ['Panaceia', 'Panakeia'],
    ['Peitho', 'Suada'],
    ['Phobus', 'Terror'],
    ['Psyche'],
    ['Themis'],
    ['Thetis'],
    ['Thyone'],
    ['Tyche', 'Fortuna', 'Tykhe'],
    ['Zelus', 'Zelos'],
    ['Leucippis', 'Leucippides', 'Leukippis', 'Leukippides', 'Hilaeira', 'Phoibe'],
    ['Moirae', 'Parcae', 'Fatum', 'Fatae', 'Klotho', 'Lakhesis', 'Atropos', 'Aisa'],
    ['Dioscuri', 'Dioscurus', 'Tyndaridae', 'Kastor', 'Polydeukes', 'Polydeuces', 'Pollux', 'Tyndaridai'],
    ['Erotes', 'Cupides' 'Anteros', 'Hedylogos', 'Hermaphroditos', 'Himeros', 'Hymenaios', 'Hymenaeus', 'Pothos'],
    ['Horae', 'Hora', 'Horai', 'Pax', 'Justitia', 'Eunomia', 'Dike', 'Dice', 'Eirene', 'Thallo', 'Karpo', 
     'Auxo', 'Auxesia', 'Damia', 'Euporia', 'Orthosie', 'Pherousa', 'Eiar', 'Theros', 'Kheimon', 'Phthinoporon'],
    ['Charites', 'Graces', 'Gratiae', 'Gratia', 'Graces', 'Aglaia', 'Euphrosyne', 'Thaleia', 'Kharis', 
     'Pasithea', 'Auxo', 'Hegemone', 'Thallo', 'Phaenna', 'Kleta', 'Peitho', 'Eudaimonia', 'Paidia', 
     'Pandaisia', 'Pannykhis', 'Antheia'], 
    ['Musae', 'Muse', 'Muses', 'Kleio', 'Euterpe', 'Thaleia', 'Melpomene', 'Terpsikhore', 'Erato', 'Polyhymnia', 
     'Kalliope', 'Ourania', 'Polymatheia', 'Melete', 'Aoede', 'Mneme', 'Melete', 'Aode', 'Arkhe', 'Thelxinoe', 
     'Nete', 'Mese', 'Hypate', 'Kephiso', 'Apollonis', 'Borysthenis', 'Neilo', 'Tritone', 'Asopo', 'Heptapora', 
     'Akhelois', 'Tipoplo', 'Rhodia', 'Calliope'],
    ['Oceanides', 'Okeanides', 'Oceanids', 'Oceanid', 'Peitho', 'Admete', 'Ianthe', 'Elektra', 'Doris', 'Prymno', 
     'Ourania', 'Hippo,' 'Klymene', 'Rhodeia', 'Kallirhoe', 'Zeuxo', 'Klytia', 'Eidyia', 'Pasithoe', 'Plexaure', 
     'Galaxaura', 'Dione', 'Melobosis', 'Thoe', 'Polydora', 'Kerkeis', 'Plouto', 'Xanthe', 'Akaste', 'Perseis', 
     'Ianeira', 'Petriae', 'Europa', 'Metis', 'Eurynome', 'Telesto', 'Khryseis', 'Asia', 'Kalypso', 'Eudora', 
     'Tykhe', 'Amphiro', 'Okyroe', 'Styx', 'Leukippe', 'Phaino', 'Elektra', 'Ianthe', 'Melite', 'Iakhe', 'Rhodea', 
     'Kallirhoe', 'Melobosis', 'Tykhe', 'Okyrhoe', 'Khryseis', 'Ianeira', 'Akaste', 'Admete', 'Rhodope', 'Plouto', 
     'Kalypso', 'Styx', 'Ourania', 'Galaxaura', 'Asia', 'Styx', 'Elektra', 'Doris', 'Eurynome', 'Amphitrite', 
     'Metis', 'Eidyia', 'Melia', 'Meliboea', 'Pleione', 'Kallirrhoe','Melite', 'Ianthe', 'Admete', 'Stilbo', 
     'Pasiphae', 'Polyxo', 'Eurynome', 'Euagoreis', 'Rhodope', 'Klytia', 'Metis', 'Menippe', 'Argia', 'Pleione', 
     'Kleio', 'Beroe', 'Klymene', 'Ephyra']
]

olympgods = majorolympgods + otherolympgods

# %%
# Reference for storing dictionary: https://www.dataquest.io/blog/jupyter-notebook-tips-tricks-shortcuts/
goddict = {}

for idx, namels in enumerate(olympgods):
    goddict[idx] = [namels, 0]
    
# %store goddict
# Out:
# Stored 'goddict' (dict)

# %%
mortals = [
    ['Achilles', 'Akhilleus'],
    ['Actaeon', 'Aktaion'],
    ['Adonis'],
    ['Aeneas'],
    ['Aegisthus', 'Aegisthos'],
    ['Agamemnon'],
    ['Agelaus'],
    ['Ajax'],
    ['Alkinoos', 'Alcinous'],
    ['Amymone'],
    ['Amphinomus'],
    ['Andromeda'],
    ['Antiope'],
    ['Arachne', 'Arakhne'],
    ['Arete'],
    ['Ascalabus', 'Askalabos'],
    ['Asclepius', 'Asklepios'],
    ['Atalanta'],
    ['Atreus'],
    ['Bellerophon', 'Bellerophontes'],
    ['Busiris', 'Bousiris'],
    ['Callisto', 'Kallisto'],
    ['Cecrops', 'Kekrops'],
    ['Coronis', 'Koronis'],
    ['Cycnus of Colonae', 'Kyknos Kolonaios'],
    ['Cycnus of Itonus', 'Kyknos Itonios'],
    ['Cycnus of Liguria', 'Kyknos Ligyrios'],
    ['Cycnus of Thyria', 'Kyknos Thyrios'],
    ['Cyparissus', 'Kyparissos'],
    ['Cyrene', 'Kyrene'],
    ['Danae'],
    ['Deucalion', 'Deukalion'],
    ['Demodocus'],
    ['Dolius'],
    ['Diomedes of Thrace', 'Diomedes Thrakios'],
    ['Endymion'],
    ['Erysichthon', 'Erysikhthon'],
    ['Eryx'],
    ['Eumaeus'],
    ['Europa'],
    ['Eurycleia'],
    ['Eurylochos', 'Eurylochus'],
    ['Eurymachus'],
    ['Eupeithes'],
    ['Evadne', 'Euadne'],
    ['Geryon', 'Geryones'],
    ['Hektor', 'Hector'],
    ['Hippolyte'],
    ['Hyacinthus', 'Hyakinthos'],
    ['Iamos', 'Iamus'],
    ['Iasion'],
    ['Icarius', 'Ikarios'],
    ['Io'],
    ['Ixion'],
    ['Jason', 'Iason'],
    ['Leda'],
    ['Lycaon', 'Lykaon'],
    ['Lycurgus', 'Lykourgos'],
    ['Meleager', 'Meleagros'],
    ['Melanthius'],
    ['Menelaus', 'Menelaos'],
    ['Midas'],
    ['Minyades'],
    ['Narcissus', 'Narkissos'],
    ['Nausicaa', 'Naucicaa'],
    ['Nestor'],
    ['Odysseus', 'Odyseus'],
    ['Oedipus', 'Oidipous'],
    ['Orion'],
    ['Otrera'],
    ['Pandora'],
    ['Paris'],
    ['Pasiphae'],
    ['Pelops'],
    ['Penthesilea', 'Penthesileia'],
    ['Penelope'],
    ['Perseus'],
    ['Peleus'],
    ['Peisistratus'],
    ['Polybus'],
    ['Phaethon'],
    ['Phaedra'],
    ['Psyche', 'Psykhe'],
    ['Pygmalion'],
    ['Pyrrha'],
    ['Salmoneus'],
    ['Sisyphus', 'Sisyphos'],
    ['Tantalus', 'Tantalos'],
    ['Teiresias', 'Tiresias'],
    ['Telemachus', 'Telemachos'],
    ['Tennes'],
    ['Theseus'],
    ['Thyestes'],
    ['Tithonus', 'Tithonos'],
    ['Triptolemus', 'Triptolemos'],
    ['Tyro'],
    ['Acamas'],
    ['Adrastus'],
    ['Agenor'],
    ['Aias'],
    ['Anchises'],
    ['Andromache'],
    ['Antilochus'],
    ['Antiphus'],
    ['Asteropaeus'],
    ['Autolycus'],
    ['Automedon'],
    ['Briseis'],
    ['Calchas'],
    ['Capaneus'],
    ['Cassandra'],
    ['Deiphobus'],
    ['Deïphobus'],
    ['Diomedes'],
    ['Eetion'],
    ['Epeius'],
    ['Eumelus'],
    ['Eurypylus'],
    ['Helenus'],
    ['Idomeneus'],
    ['Ilus'],
    ['Irus'],
    ['Laodamas'],
    ['Laomedon'],
    ['Machaon'],
    ['Meges'],
    ['Memnon'],
    ['Meriones'],
    ['Neleus'],
    ['Neoptolemus'],
    ['Niobe'],
    ['Nireus'],
    ['Oeneus'],
    ['Oileus'],
    ['Orestes'],
    ['Oïleus'],
    ['Panthous'],
    ['Patroclus'],
    ['Peirithous'],
    ['Peneleos'],
    ['Philoctetes'],
    ['Poeas'],
    ['Polydamas'],
    ['Priam'],
    ['Protesilaus'],
    ['Sthenelus'],
    ['Talthybius'],
    ['Telamon'],
    ['Telephus'],
    ['Teucer'],
    ['Tlepolemus'],
    ['Tydeus']
]

# %%
mortaldict = {}

for idx, namels in enumerate(mortals):
    mortaldict[idx] = [namels, 0]
    
for key in mortaldict.keys():
    print(mortaldict[key])

# %store mortaldict
# Out:
# [['Achilles', 'Akhilleus'], 0]
# [['Actaeon', 'Aktaion'], 0]
# [['Adonis'], 0]
# [['Aeneas'], 0]
# [['Aegisthus', 'Aegisthos'], 0]
# [['Agamemnon'], 0]
# [['Agelaus'], 0]
# [['Ajax'], 0]
# [['Alkinoos', 'Alcinous'], 0]
# [['Amymone'], 0]
# [['Amphinomus'], 0]
# [['Andromeda'], 0]
# [['Antiope'], 0]
# [['Arachne', 'Arakhne'], 0]
# [['Arete'], 0]
# [['Ascalabus', 'Askalabos'], 0]
# [['Asclepius', 'Asklepios'], 0]
# [['Atalanta'], 0]
# [['Atreus'], 0]
# [['Bellerophon', 'Bellerophontes'], 0]
# [['Busiris', 'Bousiris'], 0]
# [['Callisto', 'Kallisto'], 0]
# [['Cecrops', 'Kekrops'], 0]
# [['Coronis', 'Koronis'], 0]
# [['Cycnus of Colonae', 'Kyknos Kolonaios'], 0]
# [['Cycnus of Itonus', 'Kyknos Itonios'], 0]
# [['Cycnus of Liguria', 'Kyknos Ligyrios'], 0]
# [['Cycnus of Thyria', 'Kyknos Thyrios'], 0]
# [['Cyparissus', 'Kyparissos'], 0]
# [['Cyrene', 'Kyrene'], 0]
# [['Danae'], 0]
# [['Deucalion', 'Deukalion'], 0]
# [['Demodocus'], 0]
# [['Dolius'], 0]
# ...

# %%
import json

with open('mortaldict.json', 'w') as f:
    json.dump(mortaldict, f)
with open('goddict.json', 'w') as f:
    json.dump(goddict, f)
